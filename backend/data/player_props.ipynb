# %%
import nfl_data_py as nfl

# %%
df = nfl.clean_nfl_data(nfl.import_weekly_data(years=[2021, 2022]))
# Out:
# Downcasting floats.

# %%
df[[]].tail()
# Out:
#        player_id player_name player_display_name position position_group  \
# 1250  00-0038129     C.Otton          Cade Otton       TE             TE
# 1251  00-0038129     C.Otton          Cade Otton       TE             TE
# 1252  00-0038134    K.Walker      Kenneth Walker       RB             RB
# 1253  00-0038134    K.Walker      Kenneth Walker       RB             RB
# 1254  00-0038134    K.Walker      Kenneth Walker       RB             RB
#
#                                            headshot_url recent_team  season  \
# 1250  https://static.www.nfl.com/image/private/f_aut...          TB    2022
# 1251  https://static.www.nfl.com/image/private/f_aut...          TB    2022
# 1252  https://static.www.nfl.com/image/private/f_aut...         SEA    2022
# 1253  https://static.www.nfl.com/image/private/f_aut...         SEA    2022
# 1254  https://static.www.nfl.com/image/private/f_aut...         SEA    2022
#
#       week season_type  ...  receiving_first_downs  receiving_epa  \
# ...
